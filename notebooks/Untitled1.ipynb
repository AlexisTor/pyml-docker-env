# %%
import pandas as pd
myDict={"Nombre":["pepe", "majo","roberto"],"edad":[34,43,23],"sexo":["m","f","m"]}
df=pd.DataFrame(myDict)
df
# Out:
#     Nombre  edad sexo
# 0     pepe    34    m
# 1     majo    43    f
# 2  roberto    23    m

# %%
df.set_index("Nombre")
df
#df.loc["pepe","edad"]
# Out:
#     Nombre  edad sexo
# 0     pepe    34    m
# 1     majo    43    f
# 2  roberto    23    m

# %%
import requests
r = requests.get('https://www.opendata.euskadi.eus/contenidos/ds_informes_estudios/covid_19_2020/opendata/generated/covid19-deceasedPeopleCount.json')
data = r.text
data
#df = pd.json_normalize(r,'byDate')
#df
# Out:
# '{\n  "lastUpdateDate" : "2023-09-22T07:17:22Z",\n  "deceasedTotalCount" : 0,\n  "byDate" : [ {\n    "date" : "2020-03-01T22:00:00Z",\n    "deceasedCount" : 0\n  }, {\n    "date" : "2020-03-02T22:00:00Z",\n    "deceasedCount" : 0\n  }, {\n    "date" : "2020-03-03T22:00:00Z",\n    "deceasedCount" : 0\n  }, {\n    "date" : "2020-03-04T22:00:00Z",\n    "deceasedCount" : 1\n  }, {\n    "date" : "2020-03-05T22:00:00Z",\n    "deceasedCount" : 0\n  }, {\n    "date" : "2020-03-06T22:00:00Z",\n    "deceasedCount" : 0\n  }, {\n    "date" : "2020-03-07T22:00:00Z",\n    "deceasedCount" : 2\n  }, {\n    "date" : "2020-03-08T22:00:00Z",\n    "deceasedCount" : 2\n  }, {\n    "date" : "2020-03-09T22:00:00Z",\n    "deceasedCount" : 1\n  }, {\n    "date" : "2020-03-10T22:00:00Z",\n    "deceasedCount" : 0\n  }, {\n    "date" : "2020-03-11T22:00:00Z",\n    "deceasedCount" : 5\n  }, {\n    "date" : "2020-03-12T22:00:00Z",\n    "deceasedCount" : 4\n  }, {\n    "date" : "2020-03-13T22:00:00Z",\n    "deceas
# ...
